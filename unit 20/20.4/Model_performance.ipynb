# %%
import pandas as pd
data = {'Model':['1', '2','3','4','5','6','7'],
        'Precision':['0.90', '0.30','0.04','0.93','0.94','0.78','0.95'],
        'Recall':['0.77','0.30','0.04','0.78','0.78','0.78','0.75'],
        'ROC':['0.958','0.958','0.958','0.958','0.981','0.951','0.981'],
        'Note':['Random Forest','Isolation Forest','Local outlier Factor','XGBoost','Model Adjustment','RF:bootstrap=True','Voting classifier']}
df=pd.DataFrame (data, columns=['Model','Precision','Recall','ROC','Note'])
df
# Out:
#   Model Precision Recall    ROC                  Note
# 0     1      0.90   0.77  0.958         Random Forest
# 1     2      0.30   0.30  0.958      Isolation Forest
# 2     3      0.04   0.04  0.958  Local outlier Factor
# 3     4      0.93   0.78  0.958               XGBoost
# 4     5      0.94   0.78  0.981      Model Adjustment
# 5     6      0.78   0.78  0.951     RF:bootstrap=True
# 6     7      0.95   0.75  0.981     Voting classifier
